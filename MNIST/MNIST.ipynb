# %%
from cnn import CNN
# %matplotlib inline

# %%
cnn = CNN()
cnn.train(100)

# %%
cnn.plot_training_result()

# %%
# confusion matrix based on random half of the training set
cnn.plot_confusion_matrix()

# %%
# show 25 misclassified image, title: "true label"/"pred label"
cnn.plot_misclassification()

# %%
# plot activation of layers of a random training example
cnn.plot_activation()
